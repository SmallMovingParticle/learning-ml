# %%
import pandas as pd

# %% [markdown]
# ## series- an array like object
# ## data frame is a tablular two dimentional size mutable and hetrogeneous tabular data structure with labled axes

# %%
## series

data= [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
## series from dectionary
data = {'a':1 , 'b': 2 , "c":3}
pd.Series(data)
## key becomes the indx and value becomes the data
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30,40,45]
index=['a','b','c','d','e']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    45
# dtype: int64

# %%
##dataframe
## creating from dectionary

data= {'name':['vani' , 'dev' , 'anupam'],
       'age':[20,29,34],
       'city':['delhi' , 'mumbai' , ' meerut']}

print(data)

Df=pd.DataFrame(data)
print(Df)
index = index=['a','b','c']
# Out:
# {'name': ['vani', 'dev', 'anupam'], 'age': [20, 29, 34], 'city': ['delhi', 'mumbai', ' meerut']}
#      name  age     city
# 0    vani   20    delhi
# 1     dev   29   mumbai
# 2  anupam   34   meerut

# %%
index = index=['a','b','c']
Df=pd.DataFrame(data , index=index)
print(Df)
# Out:
#      name  age     city
# a    vani   20    delhi
# b     dev   29   mumbai
# c  anupam   34   meerut

# %%
import numpy as np
np.array(Df)
# Out:
# array([['vani', 20, 'delhi'],
#        ['dev', 29, 'mumbai'],
#        ['anupam', 34, ' meerut']], dtype=object)

# %%
data = [
    {'name':['vani' , 'dev' , 'anupam'],
       'age':[20,29,34],
       'city':['delhi' , 'mumbai' , ' meerut']}
       ]

# %%
df=pd.read_csv('people-100.csv')

# %%
df.head(5)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
df.tail(10)
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 90     91  F0aeC9c2759F3C6     Alison      Nixon  Female
# 91     92  d6EA619A7C4aA95      Jamie      Hardy  Female
# 92     93  2A33E7Cad1bb0F5     Melody        Cox  Female
# 93     94  d181FFB7d3E68bb     Xavier       Cole    Male
# 94     95  feaBf8dAE0C0d6F     Dillon     Guzman  Female
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                 Phone Date of birth  \
# 90          zmiles@example.net            3506680871    1941-07-10
# 91   sheenadouglas@example.com   (900)803-9295x11533    1994-07-17
# 92          evan90@example.org    (626)520-5080x3511    1974-07-30
# ...

# %%
##acessing the dats from df

df['Index']
type(df['Index'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0]
##ill give 0th row
# Out:
# Index                                 1
# User Id                 88F7B33d2bcf9f5
# First Name                       Shelby
# Last Name                       Terrell
# Sex                                Male
# Email              elijah57@example.net
# Phone            001-084-906-7849x73518
# Date of birth                1945-10-26
# Job Title               Games developer
# Name: 0, dtype: object

# %%
df.loc[0][2]
# Out:
# C:\Users\chaud\AppData\Local\Temp\ipykernel_33040\2880214942.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][2]
# 'Shelby'
